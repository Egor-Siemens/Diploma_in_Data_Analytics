# %% [markdown]
# # Диплом
#
#
# [Постановка задачи](#Постановка-задачи) <br>
# [Codebook](#Codebook)<br>
# [Требования к работе](#Требования-к-работе)<br>
# [Критерии оценивания](#Критерии-оценивания)<br>
# [Дополнительные материалы](#Дополнительные-материалы) <br>

# %% [markdown]
# ## Постановка задачи
#
# Как и любой бизнес, компания «Мегафон» хочет повысить удовлетворённость своих клиентов качеством услуг. Это важная задача для удержания пользователей — как давних, так и недавно привлечённых. Ведь затраты на маркетинг и продвижение не оправдаются, если клиент уйдёт из-за низкого качества связи. Однако в реальном мире ресурсы всегда ограничены, и в единицу времени технический отдел может решить конечное количество задач. <br>
# Чтобы делать это наиболее эффективно, важно определить, какие технические показатели качества связи сильнее всего влияют на удовлетворённость клиентов, и в первую очередь направить ресурсы на работу с ними. Для этого «Мегафон» провёл опрос своих клиентов, предложив им оценить уровень удовлетворённости качеством связи. По каждому клиенту, прошедшему опрос, были собраны технические показатели. <br>
# Подготовьте исследование для компании «Мегафон» и проанализируйте, как зависит (и зависит ли) оценка, которую ставит клиент в опросе, от технических показателей, которые были собраны. <br><br><br>
#
# **Более подробно о проведённом опросе:**
#
# В ходе опроса компания «Мегафон» предложила своим клиентам оценить уровень удовлетворённости качеством связи по десятибалльной шкале (где 10 — это «отлично», а 1 — «ужасно»). Если клиент оценивал качество связи на 9 или 10 баллов, опрос заканчивался. Если клиент ставил оценку ниже 9, задавался второй вопрос — о причинах неудовлетворённости качеством связи с предоставленными пронумерованными вариантами ответа. Ответ можно было дать в свободном формате или перечислить номера ответов через запятую. Ниже вы можете ознакомиться с инфографикой по структуре опроса.<br>
#
# *Обратите, пожалуйста, внимание, что для работы вам даны реальные данные, что может повлечь необходимость в дополнительной их обработке.*

# %% [markdown]
# ![](https://sun9-32.userapi.com/C6vN5pHQW7hlseIt0AtTN7qNDQbDnHXdt1P2NA/ILntXqa-RrA.jpg)

# %% [markdown]
# ## Codebook
#
# `megafon.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `user_id` — идентификатор абонента;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Q1` — ответ на первый вопрос;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Q2` — ответ на второй вопрос;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Total Traffic(MB)` — объем трафика передачи данных <sup>1 </sup>; <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Downlink Throughput(Kbps)` — средняя скорость «к абоненту» <sup>2 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Uplink Throughput(Kbps)`— средняя скорость «от абонента» <sup>3 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Downlink TCP Retransmission Rate(%)` — частота переотправок пакетов «к абоненту» <sup>4 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Video Streaming Download Throughput(Kbps)` — скорость загрузки потокового видео <sup>5 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Video Streaming xKB Start Delay(ms)` — задержка старта воспроизведения видео <sup>6 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Web Page Download Throughput(Kbps)` — скорость загрузки web-страниц через браузер <sup>7 </sup>;<br>
# &nbsp;&nbsp;&nbsp;&nbsp; `Web Average TCP RTT(ms)` — пинг при просмотре web-страниц<sup>8 </sup>.<br>
#
#
# <sup>1 </sup> — Насколько активно абонент использует мобильный интернет.<br>
# <sup>2 </sup> — Считается по всему трафику передачи данных.<br>
# <sup>3 </sup> — Считается по всему трафику передачи данных.<br>
# <sup>4 </sup> — Чем выше, тем хуже. Если в канале возникает ошибка, пакет переотправляется. Снижается полезная скорость.<br>
# <sup>5 </sup> — Чем выше, тем лучше — меньше прерываний и лучше качество картинки.<br>
# <sup>6 </sup> — Сколько времени пройдёт между нажатием на кнопку Play и началом воспроизведения видео. Чем меньше это время, тем быстрее начинается воспроизведение.<br>
# <sup>7 </sup> — Чем выше, тем лучше.<br>
# <sup>8 </sup> — Чем меньше, тем лучше — быстрее загружаются web-страницы.<br>
#
# Первый технический показатель представлен как сумма за период в одну неделю перед участием в опросе. Остальные технические показатели отображают среднее значение по данному признаку за период в одну неделю перед участием в опросе.

# %% [markdown]
# # Требования к работе
#
# Составьте работу из нескольких частей, в каждой из которых формулируется вопрос к данным или статистическая гипотеза о данных, например:
# * На основании данных какое самое вероятное значение величины X? Каков доверительный интервал для неё?
# * Верно ли, что для групп A и B значения величины X статистически достоверно различаются? На сколько?
#
# И далее по результатам анализа дайте развёрнутый ответ на этот вопрос.
#
# Сделайте **минимум три части** в работе, максимальное количество частей не ограничено. Хотя бы одна из них должна быть связана с первым вопросом из опроса «Мегафона» и хотя бы одна — со вторым. Организуйте **каждую** из частей в соответствии со следующей структурой:
#
# 1. **Постановка задачи**
#
#    **Что** Вы хотите проанализировать и **зачем**?
#     <br><br> Опишите предмет анализа с обоснованием его выбора. Почему вы хотите исследовать это предположение? Как ответ на этот вопрос поможет компании «Мегафон» с точки зрения бизнеса?<br><br>
#
# 2. **Блок с разведочным анализом**
#
#    Перед тем, как проверить своё предположение статистическими методами, посмотрите, что в данных имеется соответствующий «сигнал». Сделайте необходимые визуализации и опишите видимые тенденции в данных.<br><br>
#
# 3. **Блок со статистическим тестом**
#
#    Выберите метод для статистической проверки вашего предположения, письменно обоснуйте свой выбор. Проверьте, удовлетворяет ли выборка допущениям (assumptions) выбранного вами теста. Реализуйте тест и на основании результатов сформируйте вывод.<br><br>
#
# 4. **Вывод**
#
#    Обобщите результаты вашего анализа. Проговорите ещё раз ваше изначальное предположение, изложите вывод по результатам статистичекого анализа. Если ваше предположение не подтвердилось, напишите, как вы думаете, почему так получилось.
# <br><br>
#
#
#
# На проверку отправьте два документа:
# 1. Ноутбук с проведённым анализом и кодом решения.
# 2. Презентация результатов, которая будет использована для защиты работы перед комиссией (файл в формате PDF).
# <br><br>
# Рекомендации по структуре презентации можно найти [по ссылке](https://docs.google.com/document/d/1oD3xe_xPKuhOIvjyaaM5KLM4cegycjo2kRIOHs3hoyw/edit?usp=sharing).

# %% [markdown]
# ## Критерии оценивания
#
# **Общие критерии:** <br>
# Каждый шаг анализа должен быть обоснован. Когда вы формулируете вопрос для исследования, обоснуйте, как ответ на него поможет компании «Мегафон» решить поставленную задачу. Если выбираете определённый способ визуализации, обоснуйте, почему такой способ отображения данных лучше всего подходит для данного типа данных. Если выбираете определённый статистический тест, обоснуйте, почему этот тест подходит для проверки вашего предположения. Если вы делаете очистку или обработку данных, обоснуйте, почему такая обработка (конкретный шаг) необходима. <br><br>
#
# ***При отсутствии обоснования хотя бы по одному из шагов работа не проверяется и отправляется на доработку.***
#
# <br>
#
# **Критерии оценки кода:**
# - Корректность реализации той задачи, которая была поставлена.
# - Соблюдение основных стандартов стиля по PEP8 (пробелы, отступы, названия переменных, единый стиль кода).
# - Комментарии или текстовое описание к каждому логическому блоку кода.
#
# **Критерии оценки визуализации:**
# - Каждый график должен иметь заголовок.
# - Оси графиков должны быть подписаны.
# - Наличие легенды, если тип графика это предполагает.
# - Соответствие типа графика тому, что предполагается объяснить этим графиком.
# - Понятность, читаемость графика.
#
# **Критерии оценки статистического анализа:**
# - Соответствие теста поставленной задаче.
# - Удовлетворение выборкой assumptions теста.
# - Корректность математических расчётов при проведении теста.

# %% [markdown]
# ## Дополнительные материалы
#
# Для выполнения этого задания вам не нужно разбираться в телекоммуникациях на уровне технического специалиста. Базового представления о терминах, используемых в Codebook, будет достаточно. Для тех, кто столкнулся с ними впервые, и тех, кто хочет освежить знания, мы подготовили несколько ссылок на полезные материалы для понимания контекста:
# <br>
#
#
# **Что такое пакет данных?**<br>
# https://ru.wikipedia.org/wiki/Пакет_(сетевые_технологии)<br><br>
# **Что такое пинг/RTT?** <br>
# https://ru.wikipedia.org/wiki/Круговая_задержка <br><br>
# **Как работает протокол TCP?**<br>
# https://youtu.be/CKUOb4htnB4<br><br>
# **Что такое ошибка в канале и как происходит переотправка пакета?**<br>
# https://accedian.com/blog/network-packet-loss-retransmissions-and-duplicate-acknowledgements/<br>

# %% [markdown]
# ---
#
# # Часть 1
#
# ## 1. Постановка задачи
#
# В первой части работы проверяется гипотеза о том, что среди ответов Q2 есть наиболее популярные причины низкой оценки Q1. Возможно найдутся паттерны общей неудовлетворенности, когда часто одна или несколько проблем из списка систематически получают определенное значение оценки Q1.
#
# Для этого я сделаю ранжирование проблем/причин низкой оценки клиентского опыта, посчитав для каждой проблемы из поля `Q2` среднюю оценку удовлетворенности из поля `Q1`.
#
# Это поможет бизнесу выделить приоритетные проблемы, а также в целом увидеть топ самых популярных причин недовольства клиентов.
#
# Также в этой части работы я очищу исходные данные от некорректных ответов, которые не подразумеваются логикой опроса.

# %% [markdown]
# ## 2. Разведочный анализ
# Необходимо проверить данные на наличие пропусков, аномалий, выбросов, ошибок.<br>
# Наблюдаются ли в них тенденции, тренды. Выяснить с чем предстоит работать.

# %%
# Импорт стандартного набора библиотек для анализа данных
import numpy as np
import pandas as pd
# Импорт библиотек для визуализации 
import plotly.express as px
import plotly.graph_objects as go
# Импорт библиотеки для работы регулярными выражениями в ответах клиентов
import re

# %% [markdown]
# Обоснование использование библиотек для визуализации: `plotly` просто удобен и эффективен в работе.

# %%
# Загрузка данных
df = pd.read_csv('megafon.csv')
df.head()
# Out:
#    user_id Q1       Q2  Total Traffic(MB)  Downlink Throughput(Kbps)  \
# 0        1  5      NaN          775.48846                     360.13
# 1        2  5        4          861.96324                    3023.54
# 2        3  1        4          261.11860                     790.96
# 3        4  8        3          179.18564                    2590.97
# 4        5  2  2, 3, 4          351.99208                     731.61
#
#    Uplink Throughput(Kbps)  Downlink TCP Retransmission Rate(%)  \
# 0                    86.56                                 3.93
# 1                   411.18                                 1.27
# 2                    34.20                                 1.79
# 3                   325.88                                 0.80
# 4                   223.54                                 1.15
#
#    Video Streaming Download Throughput(Kbps)  \
# 0                                    1859.15
# 1                                     667.47
# 2                                    1079.60
# 3                                    7053.81
# 4                                    4550.38
#
#    Video Streaming xKB Start Delay(ms)  Web Page Download Throughput(Kbps)  \
# 0                                 2309                             1007.82
# 1                                 2080                              255.36
# 2                                 6367                              535.85
# 3                                 3218                             1221.02
# 4                                 1767                             2336.56
#
#    Web Average TCP RTT(ms)
# 0                       83
# 1                      425
# 2                      485
# 3                       51
# 4                       68

# %%
# Общая информация и базовые статистики
df.info()
print(f'Количество уникальных записей {df.user_id.nunique()}')
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3112 entries, 0 to 3111
# Data columns (total 11 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   user_id                                    3112 non-null   int64
#  1   Q1                                         3110 non-null   object
#  2   Q2                                         1315 non-null   object
#  3   Total Traffic(MB)                          3112 non-null   float64
#  4   Downlink Throughput(Kbps)                  3112 non-null   float64
#  5   Uplink Throughput(Kbps)                    3112 non-null   float64
#  6   Downlink TCP Retransmission Rate(%)        3112 non-null   float64
#  7   Video Streaming Download Throughput(Kbps)  3112 non-null   float64
#  8   Video Streaming xKB Start Delay(ms)        3112 non-null   int64
#  9   Web Page Download Throughput(Kbps)         3112 non-null   float64
#  10  Web Average TCP RTT(ms)                    3112 non-null   int64
# dtypes: float64(6), int64(3), object(2)
# memory usage: 267.6+ KB
# Количество уникальных записей 3112
#            user_id  Total Traffic(MB)  Downlink Throughput(Kbps)  \
# count  3112.000000        3112.000000                3112.000000
# mean   1556.500000         406.282339                2220.774023
# std     898.501345         220.593815                2629.824405
# min       1.000000         100.026680                  13.260000
# 25%     778.750000         214.261192                 652.297500
# 50%    1556.500000         363.999720                1404.230000
# 75%    2334.250000         572.524325                2823.645000
# max    3112.000000         887.078270               39817.640000
#
#        Uplink Throughput(Kbps)  Downlink TCP Retransmission Rate(%)  \
# count              3112.000000                          3112.000000
# mean                170.702381                             1.834518
# std                 204.031286                             2.074593
# min                   6.110000                             0.050000
# 25%                  70.735000                             0.720000
# 50%                 119.435000                             1.300000
# 75%                 210.617500                             2.240000
# max                4141.850000                            31.200000
#
#        Video Streaming Download Throughput(Kbps)  \
# count                                3112.000000
# mean                                 5728.806848
# std                                  5161.475235
# min                                     0.000000
# 25%                                  2324.550000
# 50%                                  4436.500000
# 75%                                  7611.440000
# max                                 58566.030000
#
#        Video Streaming xKB Start Delay(ms)  \
# count                          3112.000000
# mean                           2107.596080
# std                            1582.423057
# min                             239.000000
# 25%                            1280.000000
# 50%                            1672.000000
# 75%                            2312.000000
# max                           21392.000000
#
#        Web Page Download Throughput(Kbps)  Web Average TCP RTT(ms)
# count                         3112.000000              3112.000000
# mean                          2100.258901               194.195051
# std                           2062.509549               267.387914
# min                              0.000000                 0.000000
# 25%                           1018.002500                74.000000
# 50%                           1670.695000               118.000000
# 75%                           2519.987500               207.000000
# max                          35603.970000              3471.000000

# %%
# Количество ответов из поля Q1, имеющих два или менее повторов 
# Число повторов менее двух говорит о том, что эти ответы специфичны и выделяются

wrong_answers = df.Q1.value_counts()[df.Q1.value_counts()<=2]
print(wrong_answers)
print(f'Общее количество ответов, отделяющихся стилистикой от большинства: {wrong_answer.sum()}')
# Out:
# 1, 3                                                                    2
# 5, 6                                                                    2
# Нет                                                                     2
# Да                                                                      2
# Ужасно                                                                  1
# ?                                                                       1
# Поохое                                                                  1
# Очень  хорошо. Обслуживания  я довольно. Спасибо вам.555                1
# Когда в Москве-10 а когда в калужской области в деревне Бели-1          1
# 1, 8                                                                    1
# 3 тройка, связь отвратительная, жалко платить за такой тарив            1
# Чдтчдтччдтччч                                                           1
# 3, 7                                                                    1
# 20, 89031081392                                                         1
# Немагу дать атценку денги незашто снимаеть скоро выклучаю               1
# Без з                                                                   1
# 10, 5                                                                   1
# 2, 5                                                                    1
# 10, 50                                                                  1
# Пока не понял                                                           1
# 4. Тульская область Заокский район. Романовские дачи связи почти нет    1
# Hi                                                                      1
# 11                                                                      1
# 2, 9                                                                    1
# 19                                                                      1
# 15                                                                      1
# 1, 6                                                                    1
# ***** ** ***                                                            1
# 3 - дер.Ширяево Волоколамского района, 9 - в Москве                     1
# 10, 9                                                                   1
# Чем даль ше,тем лучше.Спасибо за ваш труд.Оценка 10 !                   1
# ОЦЕНКА-3/НЕВАЖНО/                                                       1
# Отвратительно                                                           1
# Я ценой услуг не удовлетворен                                           1
# 3, 9                                                                    1
# 0, 1, 5                                                                 1
# 5, 7                                                                    1
# Я в Смол. Области живу сейчас, не пользуюсь телефоном совсем            1
# Name: Q1, dtype: int64
# Общее количество ответов, отделяющихся стилистикой от большинства: 42

# %% [markdown]
# Поскольку единожды употребляемых ответов много, не буду визуализировать их на графике чтобы не портить его читаемость

# %%
# Массив ответов на опрос №1 (для визуальной оценки структуры наполнения ответов)
count_answers_Q1 = df.Q1.value_counts()[df.Q1.value_counts()>2]

fig = go.Figure()
fig.add_trace(go.Bar(x=count_answers_Q1.index,
                     y=count_answers_Q1.values,

))
fig.update_layout(title='Количество ответов в поле Q1',
                  xaxis_title='Оценки удовлетворения качества услуг',
                  yaxis_title='Кол-во')
fig.show()
# Out:
# <div>                            <div id="f69bfb1d-a493-45f8-8f18-a026255fa5f4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f69bfb1d-a493-45f8-8f18-a026255fa5f4")) {                    Plotly.newPlot(                        "f69bfb1d-a493-45f8-8f18-a026255fa5f4",                        [{"x":["10","1","3","8","9","5","7","2","4","6","0"],"y":[846,532,325,291,238,234,200,168,123,101,10],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %%
# Массив ответов на опрос №2
count_answers_Q2 = df.Q2.value_counts()[df.Q2.value_counts()>=10] # для читаемости

fig = go.Figure()
fig.add_trace(go.Bar(x=count_answers_Q2.values,
                     y=count_answers_Q2.index,
                     orientation='h'

))
fig.update_layout(title='Количество ответов в поле Q2',
                  yaxis_title='Код проблемы или комбинация кодов',
                  xaxis_title='Кол-во')
fig.show()
# Out:
# <div>                            <div id="e0a6498a-b782-4d03-9e20-fcfcae6a4e17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0a6498a-b782-4d03-9e20-fcfcae6a4e17")) {                    Plotly.newPlot(                        "e0a6498a-b782-4d03-9e20-fcfcae6a4e17",                        [{"orientation":"h","x":[190,170,168,121,85,76,64,56,45,44,40,30,27,27,22,18,12,11,11,11,10],"y":["3","4","1","1, 3","3, 4","1, 3, 4","7","1, 4","3, 4, 5","1, 2, 3","1, 3, 4, 5","4, 5","1, 4, 5","1, 2, 3, 4, 5","1, 2","1, 2, 3, 4","2, 3","2","2, 3, 4","1, 2, 4","6"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pa ...

# %% [markdown]
# В зависимости от оценок, разделю опрошенных на три группы:
# * perfect - всем довольны
# * normal поставили оценку 7-8 (выше половины в шкале, но не идеально)
# * bad - не довольны (оценка 6 и ниже)

# %%
# Доли ответов
# Заполняю цифрами, а не переменными потому что они есть выше на графике Q1 и их удобно смотреть
perfect = round((846+238) / 3110 * 100, 2) # кол-во ответов 10, 9
normal = round((291+200) / 3110 * 100, 2) # кол-во ответов 8, 7
bad = round((3110 - (846+238) - (291+200)) / 3110 * 100, 2) # остальные

print(f'Из участвовавших в опросе Q1 клиентов:\nабсолютно удовлетворено: {perfect}%'
     + f'\nпоставили оценку 7 или 8: {normal}%'
     + f'\nнедовольны: {bad}%')

# Визуализация в виде барчартов
fig = go.Figure()
fig.add_trace(go.Bar(x=['perfect', 'normal', 'bad'],
                     y=[perfect, normal, bad]))
fig.update_layout(title='Распределение клиентов по удовлетворенности качеством услуг', 
                  xaxis_title='Группы',
                  yaxis_title='%')
# Out:
# Из участвовавших в опросе Q1 клиентов:
# абсолютно удовлетворено: 34.86%
# поставили оценку 7 или 8: 15.79%
# недовольны: 49.36%
# <div>                            <div id="232c572f-f466-4aba-a06e-c9ad663a1959" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("232c572f-f466-4aba-a06e-c9ad663a1959")) {                    Plotly.newPlot(                        "232c572f-f466-4aba-a06e-c9ad663a1959",                        [{"x":["perfect","normal","bad"],"y":[34.86,15.79,49.36],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colo ...

# %% [markdown]
# Уже можно сказать, что в опросе приняло участие 3110 человек.<br>
# Около 50% пользователей оценили услуги мегафона менее 7 баллов, стоит разобраться в причинах таких оценок, выделить наиболее популярные проблемы, приоритетные.
#
# Среди значений в поле `Q1` есть 42 ответа с отличающейся структурой, я не буду использовать их, поскольку это накладывает дополнительные сложности в виде работы с контекстом, а также невозможности выразить их объективно в числовой шкале, в силу наличия разных аргументов логики таких ответов. Ко всему прочему, 42 ответа это примерно 1% от общего числа ответов и у них нет пары в поле `Q2`.

# %% [markdown]
# ## 3. Блок со статистическим тестом
#
# В качестве статистического метода использую расчет среднего, это хорошо отразит цель задачи
#
# Перед этим данные нуждаются в небольшой предобработке

# %%
# На мой взгляд, количество упоминаний проблем или их перечня менее 5 
# - не подходит для расчета средней оценки
no_popular_answers_Q2 = df.Q2.value_counts()[df.Q2.value_counts() < 5]

# В связи с вышесказанным уберу из данных строки, содержащие некорректные ответы 
df_part1 = df[~df.Q1.isin(wrong_answer.index)
              & ~(df.Q2.isin(['0', '8', '9', '10'])) # список чисел вне диапазона Q2 1-7
              & ~(df.Q2.isin(no_popular_answers_Q2.index))].copy() # не популярные ответы

# Уберу из данных пропуски, они не отражают цели задачи
df_part1.dropna(inplace=True)

# Прведу значения Q1 к числовому формату
df_part1.Q1 = df_part1.Q1.astype('int')

# Группировка по коду проблемы или по комбинации кодов и расчет средней общей оценки
df_part1 = df_part1.groupby('Q2').agg({'Q1': 'mean'}).reset_index()
df_part1.columns = ['Q2', 'Q1 mean']
df_part1.tail()
# Out:
#       Q2   Q1 mean
# 19     4  4.470588
# 20  4, 5  4.266667
# 21     5  7.000000
# 22     6  6.900000
# 23     7  2.906250

# %% [markdown]
# Я получил среднюю оценку удовлетворения качества услуг для каждой проблемы или комбинации проблем.<br>
# Теперь я могу добавить частоту упоминаний проблем среди опрошенных клиентов.

# %%
# Количество ответов
count_answers = df.Q2.value_counts().reset_index()
count_answers.columns = ['Q2', 'Count']

# Добавляю все в одну таблицу
df_part1 = df_part1.merge(count_answers, on='Q2')
df_part1.sort_values(by=['Count'], ascending=False, inplace=True)
df_part1['Q1 mean'] = round(df_part1['Q1 mean'], 2)
df_part1.head()
# Out:
#       Q2  Q1 mean  Count
# 15     3     4.63    190
# 19     4     4.47    170
# 0      1     4.06    168
# 6   1, 3     4.34    121
# 16  3, 4     3.86     85

# %% [markdown]
# Если клиент недоволен качеством услуг и перечислил проблемы через запятую сложно оценить влияние каждого пункта. Лучше рассмотреть такие комбинации отдельно от однозначных ответов.

# %%
# Словарь для расшифровки
Decryption = {'1': 'Недозвоны, обрывы при звонках',
              '2': 'Время ожидания гудков',
              '3': 'Плохое качество связи в зданиях',
              '4': 'Медленный моб интернет',
              '5': 'Медленная загрузка видео',
              '6': 'Затрудняюсь ответить',
              '7': 'Свой вариант'}

# Датафрейм, содержащий одну причину не удовлетворенности
one_answer = df_part1[df_part1.Q2.isin(['1', '2', '3', '4', '5', '6', '7'])].copy()
